# %%
import pandas as pd
pd.options.display.max_columns = None
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support as score
from xgboost import XGBClassifier
import mlflow
import datetime
import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\pydantic\_internal\_fields.py:127: UserWarning: Field "model_server_url" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\pydantic\_internal\_config.py:269: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)

# %%
version = "v1.0"
data_url = "/data/weatherAUS.csv"

# %%
from data_processing import transform_data

# %%
import os
os.environ['MLFLOW_TRACKING_USERNAME']= "Sahar-dev"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "1a82d2e1cf9c21f919dfb44e98e6eb57fc75ab0a"

# %%
mlflow.set_tracking_uri("https://dagshub.com/Sahar-dev/weather.mlflow")
mlflow.set_experiment("Final-experiment")
# Out:
# 2023/12/01 09:50:06 INFO mlflow.tracking.fluent: Experiment with name 'Final-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/22bca6fafa764f5f9b31797f132bcceb', creation_time=1701420606417, experiment_id='8', last_update_time=1701420606417, lifecycle_stage='active', name='Final-experiment', tags={}>

# %%
#read the data
df = pd.read_csv("data\weatherAUS.csv")

# %%
#shape of the data
df.shape
# Out:
# (145460, 23)

# %%
#cleaning and preprocessing
X_train,X_test,y_train,y_test = transform_data(df)

# %%
mlflow.sklearn.autolog(disable=True)

# %%
with mlflow.start_run(run_name='LogisticRegression'):
    mlflow.log_param("data_url",data_url)
    mlflow.log_param("data_version",version)
    mlflow.log_param("input_rows",df.shape[0])
    mlflow.log_param("input_cols",df.shape[1])
    #model fitting and training
    lr=LogisticRegression()
    mlflow.set_tag(key= "model",value="LogisticRegression")
    params = lr.get_params()
    mlflow.log_params(params)
    lr.fit(X_train,y_train)
    train_features_name = f'{X_train=}'.split('=')[0]
    train_label_name = f'{y_train=}'.split('=')[0]
    mlflow.set_tag(key="train_features_name",value= train_features_name)
    mlflow.set_tag(key= "train_label_name",value=train_label_name)
    predicted=lr.predict(X_test)
    precision,recall,fscore,support=score(y_test,predicted,average='macro')
    mlflow.log_metric("Precision_test",precision)
    mlflow.log_metric("Recall_test",recall)
    mlflow.log_metric("F1_score_test",fscore)
    mlflow.sklearn.log_model(lr,artifact_path="ML_models")

# %%
# disable autologging
mlflow.sklearn.autolog(disable=True)

# %%
with mlflow.start_run(run_name='RandomForest'):
    mlflow.log_param("data_url",data_url)
    mlflow.log_param("data_version",version)
    mlflow.log_param("input_rows",df.shape[0])
    mlflow.log_param("input_cols",df.shape[1])
    rf = RandomForestClassifier(random_state=5)
    mlflow.set_tag(key="model", value = "RandomForest")
    params = rf.get_params()
    mlflow.log_params(params)
    rf.fit(X_train,y_train)
    train_features_name = f'{X_train=}'.split('=')[0]
    train_label_name = f'{y_train=}'.split('=')[0]
    mlflow.set_tag(key="train_features_name",value= train_features_name)
    mlflow.set_tag(key= "train_label_name",value=train_label_name)
    predicted=rf.predict(X_test)
    precision,recall,fscore,support=score(y_test,predicted,average='macro')
    mlflow.log_metric("Precision_test",precision)
    mlflow.log_metric("Recall_test",recall)
    mlflow.log_metric("F1_score_test",fscore)
    mlflow.sklearn.log_model(rf,artifact_path="ML_models")

# %%
# disable autologging
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run(run_name='XGBoost'):
    mlflow.log_param("data_url",data_url)
    mlflow.log_param("data_version",version)
    mlflow.log_param("input_rows",df.shape[0])
    mlflow.log_param("input_cols",df.shape[1])
    xg = XGBClassifier()
    params = xg.get_params()
    mlflow.set_tag(key= "model", value="XGBClassifier")
    mlflow.log_params(params)
    xg.fit(X_train,y_train)
    train_features_name = f'{X_train=}'.split('=')[0]
    train_label_name = f'{y_train=}'.split('=')[0]
    mlflow.set_tag(key="train_features_name",value= train_features_name)
    mlflow.set_tag(key= "train_label_name",value=train_label_name)
    predicted=xg.predict(X_test)
    precision,recall,fscore,support=score(y_test,predicted,average='macro')
    mlflow.log_metric("Precision_test",precision)
    mlflow.log_metric("Recall_test",recall)
    mlflow.log_metric("F1_score_test",fscore)
    mlflow.xgboost.log_model(xg,artifact_path="ML_models")

# %%
#Reading Pandas Dataframe from mlflow
all_experiments = [exp.experiment_id for exp in mlflow.search_experiments()]
df_mlflow = mlflow.search_runs(experiment_ids=all_experiments,filter_string="metrics.F1_score_test <1")
run_id = df_mlflow.loc[df_mlflow['metrics.F1_score_test'].idxmax()]['run_id']
print(run_id)
# Out:
# b279f77c54524c388f0da64e3b01586a

# %%
df_mlflow
# Out:
#                              run_id experiment_id    status  \
# 0  b279f77c54524c388f0da64e3b01586a             8  FINISHED
# 1  c585307d3fdf495683e63a6cbe58987b             8  FINISHED
# 2  a8c2426239c74818a0d598d52a4a778a             8  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/22bca6fafa764f5f9b31797f132b...
# 1  mlflow-artifacts:/22bca6fafa764f5f9b31797f132b...
# 2  mlflow-artifacts:/22bca6fafa764f5f9b31797f132b...
#
#                         start_time                         end_time  \
# 0 2023-12-01 09:03:04.646000+00:00 2023-12-01 09:03:16.083000+00:00
# 1 2023-12-01 08:57:00.657000+00:00 2023-12-01 09:02:36.007000+00:00
# 2 2023-12-01 08:55:06.030000+00:00 2023-12-01 08:55:21.285000+00:00
#
#    metrics.F1_score_test  metrics.Recall_test  metrics.Precision_test  \
# 0               0.760263             0.734460                0.805663
# 1               0.756074             0.728926                0.806298
# 2               0.738376             0.711099                0.793233
#
#   params.scale_pos_weight params.verbosity params.multi_strategy  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
#
#   params.enable_categorical params.max_delta_step params.max_leaves  \
# 0                     False                  None              None
# 1                      None                  None              None
# 2                      None                  None              None
#
#   params.reg_alpha params.eval_metric params.colsample_bylevel  \
# 0             None               None                     None
# 1             None               None                     None
# 2             None               None                     None
#
#   params.max_cat_threshold params.importance_type params.n_estimators  \
# 0                     None                   None                None
# 1                     None                   None                 100
# 2                     None                   None                None
#
#   params.validate_parameters params.colsample_bytree params.callbacks  \
# 0                       None                    None             None
# 1                       None                    None             None
# 2                       None                    None             None
#
#   params.subsample params.grow_policy params.reg_lambda params.data_version  \
# 0             None               None              None                v1.0
# 1             None               None              None                v1.0
# 2             None               None              None                v1.0
#
#   params.n_jobs params.max_cat_to_onehot params.learning_rate  \
# 0          None                     None                 None
# 1          None                     None                 None
# 2          None                     None                 None
#
#   params.input_rows params.colsample_bynode params.objective  \
# 0            145460                    None  binary:logistic
# 1            145460                    None             None
# 2            145460                    None             None
#
#   params.random_state params.feature_types params.booster  \
# 0                None                 None           None
# 1                   5                 None           None
# 2                None                 None           None
#
#         params.data_url params.interaction_constraints params.missing  \
# 0  /data/weatherAUS.csv                           None            nan
# 1  /data/weatherAUS.csv                           None           None
# 2  /data/weatherAUS.csv                           None           None
#
#   params.num_parallel_tree params.sampling_method params.gamma  \
# 0                     None                   None         None
# 1                     None                   None         None
# 2                     None                   None         None
#
#   params.early_stopping_rounds params.monotone_constraints  \
# 0                         None                        None
# 1                         None                        None
# 2                         None                        None
#
#   params.min_child_weight params.device params.input_cols params.base_score  \
# 0                    None          None                25              None
# 1                    None          None                25              None
# 2                    None          None                25              None
#
#   params.max_depth params.max_bin params.tree_method params.bootstrap  \
# 0             None           None               None             None
# 1             None           None               None             True
# 2             None           None               None             None
#
#   params.min_weight_fraction_leaf params.max_features  \
# 0                            None                None
# 1                             0.0                sqrt
# 2                            None                None
#
#   params.min_samples_split params.max_leaf_nodes params.min_impurity_decrease  \
# 0                     None                  None                         None
# 1                        2                  None                          0.0
# 2                     None                  None                         None
#
#   params.oob_score params.criterion params.verbose params.class_weight  \
# 0             None             None           None                None
# 1            False             gini              0                None
# 2             None             None              0                None
#
#   params.warm_start params.min_samples_leaf params.ccp_alpha  \
# 0              None                    None             None
# 1             False                       1              0.0
# 2             False                    None             None
#
#   params.max_samples params.penalty params.multi_class params.max_iter  \
# 0               None           None               None            None
# 1               None           None               None            None
# 2               None             l2               auto             100
#
#   params.tol params.dual params.l1_ratio params.C params.fit_intercept  \
# 0       None        None            None     None                 None
# 1       None        None            None     None                 None
# 2     0.0001       False            None      1.0                 True
#
#   params.solver params.intercept_scaling tags.train_label_name  \
# 0          None                     None               y_train
# 1          None                     None               y_train
# 2         lbfgs                        1               y_train
#
#   tags.train_features_name tags.mlflow.user tags.mlflow.runName  \
# 0                  X_train        sahar-dev             XGBoost
# 1                  X_train        sahar-dev        RandomForest
# 2                  X_train        sahar-dev  LogisticRegression
#
#                              tags.mlflow.source.name  \
# 0  c:\Users\sahas\anaconda3\envs\mlops\lib\site-p...
# 1  c:\Users\sahas\anaconda3\envs\mlops\lib\site-p...
# 2  c:\Users\sahas\anaconda3\envs\mlops\lib\site-p...
#
#                        tags.mlflow.log-model.history  \
# 0  [{"run_id": "b279f77c54524c388f0da64e3b01586a"...
# 1  [{"run_id": "c585307d3fdf495683e63a6cbe58987b"...
# 2  [{"run_id": "a8c2426239c74818a0d598d52a4a778a"...
#
#               tags.mlflow.source.git.commit tags.mlflow.source.type  \
# 0  f60408ba26398d9ba4ad8adcf2b72d1b9e022965                   LOCAL
# 1  f60408ba26398d9ba4ad8adcf2b72d1b9e022965                   LOCAL
# 2  f60408ba26398d9ba4ad8adcf2b72d1b9e022965                   LOCAL
#
#            tags.model
# 0       XGBClassifier
# 1        RandomForest
# 2  LogisticRegression

# %%
#let's call the model from the model registry ( in production stage)
import mlflow.pyfunc

logged_model = f'runs:/{run_id}/ML_models'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
print(loaded_model)

# Predict on a Pandas DataFrame.

loaded_model.predict(X_test)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# mlflow.pyfunc.loaded_model:
#   artifact_path: ML_models
#   flavor: mlflow.xgboost
#   run_id: b279f77c54524c388f0da64e3b01586a
# array([1, 0, 1, ..., 0, 1, 0])
