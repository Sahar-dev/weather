# %%
import pandas as pd
pd.options.display.max_columns=None
import numpy as np

# %%
df = pd.read_csv("data/weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       NaN     16.9     21.8        No           No
# 1       NaN     17.2     24.3        No           No
# 2       2.0     21.0     23.2        No           No
# 3       NaN     18.1     26.5        No           No
# 4       8.0     17.8     29.7        No           No

# %%
import deepchecks
deepchecks.__version__
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22000\2285237833.py in <cell line: 1>()
# ----> 1 import deepchecks
#       2 deepchecks.__version__
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\__init__.py in <module>
#      32
#      33 from deepchecks.analytics.anonymous_telemetry import validate_latest_version
# ---> 34 from deepchecks.core import (BaseCheck, BaseSuite, CheckFailure, CheckResult, Condition, ConditionCategory,
#      35                              ConditionResult, ModelOnlyBaseCheck, SingleDatasetBaseCheck, SuiteResult,
#      36                              TrainTestBaseCheck)
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\__init__.py in <module>
#      13 Import objects to be available in parent deepchecks module.
#      14 """
# ---> 15 from .check_json import CheckFailureJson, CheckResultJson
#      16 from .check_result import CheckFailure, CheckResult
#      17 from .checks import BaseCheck, DatasetKind, ModelOnlyBaseCheck, SingleDatasetBaseCheck, TrainTestBaseCheck
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\check_json.py in <module>
#      19 import plotly
#      20
# ---> 21 from deepchecks.core.check_result import CheckFailure, CheckResult, DisplayMap
#      22 from deepchecks.core.condition import Condition, ConditionCategory, ConditionResult
#      23 from deepchecks.utils.html import imagetag
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\check_result.py in <module>
#      23
#      24 from deepchecks.core.condition import ConditionCategory, ConditionResult
# ---> 25 from deepchecks.core.display import DisplayableResult, save_as_html
#      26 from deepchecks.core.errors import DeepchecksValueError
#      27 from deepchecks.core.reduce_classes import ReduceMixin
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\display.py in <module>
#      23 from ipywidgets import Widget
#      24
# ---> 25 from deepchecks.core.serialization.abc import HTMLFormatter, HtmlSerializer, IPythonSerializer, WidgetSerializer
#      26 from deepchecks.utils.ipython import is_colab_env, is_databricks_env, is_kaggle_env, is_sagemaker_env, is_sphinx
#      27 from deepchecks.utils.logger import get_logger
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\serialization\abc.py in <module>
#      22
#      23 from deepchecks.core import check_result as check_types  # pylint: disable=unused-import
# ---> 24 from deepchecks.core.serialization import common
#      25
#      26 try:
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\core\serialization\common.py in <module>
#      30 from deepchecks.core import check_result as check_types
#      31 from deepchecks.core import errors
# ---> 32 from deepchecks.utils.dataframes import hide_index_for_display, un_numpy
#      33 from deepchecks.utils.html import linktag
#      34 from deepchecks.utils.strings import truncate_string
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\utils\dataframes.py in <module>
#      17
#      18 from deepchecks.core.errors import DeepchecksValueError
# ---> 19 from deepchecks.utils.type_inference import infer_categorical_features
#      20 from deepchecks.utils.typing import Hashable
#      21 from deepchecks.utils.validation import ensure_hashable_or_mutable_sequence
#
# c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\deepchecks\utils\type_inference.py in <module>
#      16 import numpy as np
#      17 import pandas as pd
# ---> 18 from pandas.core.dtypes.common import is_datetime_or_timedelta_dtype, is_float_dtype, is_numeric_dtype
#      19 from typing_extensions import Literal
#      20
#
# ImportError: cannot import name 'is_datetime_or_timedelta_dtype' from 'pandas.core.dtypes.common' (c:\Users\sahas\anaconda3\envs\mlops\lib\site-packages\pandas\core\dtypes\common.py)

# %%
from deepchecks.tabular.suites import full_suite
suites=full_suite()
suites

# %%
cat_features= df.select_dtypes(include=['object']).columns.tolist()
cat_features

# %%
from deepchecks.tabular import Dataset
dataframeTest=Dataset(df=df,label='is_fraud',cat_features=cat_features)
dataframeTest

# %%
suites.run(dataframeTest)
